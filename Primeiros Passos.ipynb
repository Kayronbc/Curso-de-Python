# %%
#Esse sinal serve para comentar um codigo
"""
Usando 3 aspas podemos comentar varias linhas de uma vez
assim quando for executado o script pula essas linhas
"""

print("Script executado com sucesso!")
# Out:
# Script executado com sucesso!

# %%
#O que é uma variável?

inteiro = 42
print(inteiro)
# Out:
# 42

# %% [raw]
# #Principais tipos de variáveis
#
# #inteiro (int) = somente numeros inteiros, sem decimais
# inteiro = 42
#
# #Flutuante (Float) = Aceita decimais
# flutuante = 42.0
#
# #complexo (complex) = #numeros complexos tem uma parte real e uma imaginaria
# complexo = 4 + 4j
#
# print(inteiro, flutuante, complexo)
#
# #Strings (str) = sequencia de caracteres (Texto)
# texto = "Olá Mundo"
#
# #Listas (list) = coleção, ordenada e mutável
# lista = [1, 2, 3] #conteudo mutavel, pode ser alterado depois
#
# print("texto: ", texto, "/ lista: ", lista)
#
# #tuplas (tuple) = coleção, ordenada e imutável
# tupla = (1, 2, 3, 4, 5) # por ser imutável, nao pode ser alterada depois
#
# #conjuntos (Set) = coleção não ordenada de itens unicos
# conjunto = {1, 2, 3} #não aceita itens repetidos
#
# #Dicionários (dict) = coleção não ordenada de pares chave-valor
# dicionario = {"chave": "valor"}
#
# #booleano (bool) = valores verdadeiro ou falso
# booleano = true
#
# #NoneType (none) = tipo especial que representa ausencia de valor
# nenhum = none

# %%
#exemplos

idade = 30
nome = "Kayron"

print("Nome: ", nome, "/ idade: ", idade)
# Out:
# Nome:  Kayron / idade:  30

# %%
#como ver o tipo da variável

# %%
nome = "Ana Paula"

print(type(nome))

idade = "31"

print(type(idade))
# Out:
# <class 'str'>
# <class 'str'>

# %%
#Exercícios

# %%
idade = 25
nome = "João"
saldo = 100.50
soma = idade + saldo
print(soma)

nota1 = 7.5
nota2 = 8.3
nota3 = 6.9
media = (nota1 + nota2 + nota3) / 3
print(format(media, ".2f")) #o 2f define a quantidade de casas decimais
# Out:
# 125.5
# 7.57

# %%
#Input

nome = input("Digite seu nome: ")
print("O seu nome é: " + nome)

nota1 = float(input("Digite a nota 1: "))
nota2 = float(input("Digite a nota 2: "))
media = (nota1 + nota2) / 2

print("Olá", nome, "sua média foi de: ", media)
# Out:
# O seu nome é: Kayron
# Olá Kayron sua média foi de:  1.5
